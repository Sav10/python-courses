# %% [markdown]
# # Analyser des données depuis des API Web

# %% [markdown]
# Python permet de s'interfacer avec de nombreux services web (API).
#
# Dans cette partie nous verrons :
#
# - Ce qu'est une API
# - Comment Python et Pandas permettent de transformer des données brutes en un DataFrame exploitable

# %% [markdown]
# ## Introduction aux API Web

# %% [markdown]
# Une API (Application Programming Interface) permet de récupérer des des données mises à disposition par des services Web accessibles depuis une adresse particulière.
#
# La plupart des services Web (Google Analytics, Mixpanel, Twitter, Facebook, le New York Times etc..) dispose d'API ce qui en fait une source de données de choix.
#
# Python et Pandas sont d'excellents outils pour récupérer, transformer et analyser ces données web.

# %% [markdown]
# ### URLs

# %% [markdown]
# Une URL (Unique Ressource Locator) permet d'identifier de manière unique une ressource sur Internet. Prenons l'URL suivante :

# %% [raw]
# http://www.example.com/foo/bar?arg1=baz&arg2=quux

# %% [markdown]
# Cette URL se décompose en blocs logiques :
#
# - ***http://*** = le schéma, détermine le protocole que nous utilisons pour communiquer avec le service Web. Nous utiliserons principalement le protocole **http**
# - ***www.example.com*** = l'hôte qui détermine sur quel serveur de l'internet nous allons communiquer
# - ***/foo/bar*** = spécifie le chemin où se trouve la ressource
# - ***?arg1=baz&arg2=quux*** les paramètres de la requête

# %% [markdown]
# ### HTML vs JSON

# %% [markdown]
# - HTML permet de renvoyer de la donnée pour un utilisateur. Lorsqu'une requête est faite sur un serveur, celui-ci renvoie des éléments (html, css,js, etc..) permettant au navigateur d'afficher une page web **user-friendly**

# %% [markdown]
# <img src='images/html.png' width=500>

# %% [markdown]
# - JSON permet de renvoyer de la donnée structurée, exploitable par une machine. Lorsqu'un service doit communiquer avec un autre service, les données renvoyées sont **machine-friendly**. Plusieurs formats sont possibles (CSV, JSON, XML etc..)

# %% [markdown]
# <img src='images/json.png' width=500>

# %% [markdown]
# Le format JSON (Javascript Object Notation) est un des formats préférés des Web API.
#
# Il peut être composé de deux structures :
#
# - Dictionnaire clé / valeur
# - Tableaux d'objets
#
# Voici un exemple de JSON :

# %%
{
     "firstName": "John",
     "lastName": "Smith",
     "address": {
         "streetAddress": "21 2nd Street",
         "city": "New York",
         "state": "NY",
         "postalCode": 10021
     },
     "phoneNumbers": [
         "212 555-1234",
         "646 555-4567"
     ]
 }

# %% [markdown]
# ### Exemples d'API populaires

# %% [markdown]
# La plupart des services Web disposent d'API. Elles sont également documentées voici quelques exemples :

# %% [markdown]
# - Facebook - https://developers.facebook.com/tools/explorer/
# - Twitter - https://dev.twitter.com/rest/tools/console
# - Google Analytics - https://ga-dev-tools.appspot.com/explorer/
# - The New York Times - http://developer.nytimes.com/docs

# %%
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
from datetime import datetime
import requests

# %% [markdown]
# #### Api simple

# %%
#Adresse de l'api
api_astros = 'http://api.open-notify.org/astros.json'
#On utilise requests pour charger la page
r = requests.get(api_astros)
#On vérifie le si la requète s'est bien déroulée (200 = ok)
r.status_code
# Out:
# 200

# %%
#On extrait les données json
result_api = r.json()

# %%
result_api
# Out:
# {'number': 13,
#  'message': 'success',
#  'people': [{'name': 'Mark Vande Hei', 'craft': 'ISS'},
#   {'name': 'Pyotr Dubrov', 'craft': 'ISS'},
#   {'name': 'Anton Shkaplerov', 'craft': 'ISS'},
#   {'name': 'Zhai Zhigang', 'craft': 'Shenzhou 13'},
#   {'name': 'Wang Yaping', 'craft': 'Shenzhou 13'},
#   {'name': 'Ye Guangfu', 'craft': 'Shenzhou 13'},
#   {'name': 'Raja Chari', 'craft': 'ISS'},
#   {'name': 'Tom Marshburn', 'craft': 'ISS'},
#   {'name': 'Kayla Barron', 'craft': 'ISS'},
#   {'name': 'Matthias Maurer', 'craft': 'ISS'},
#   {'name': 'Oleg Artemyev', 'craft': 'ISS'},
#   {'name': 'Denis Matveev', 'craft': 'ISS'},
#   {'name': 'Sergey Korsakov.', 'craft': 'ISS'}]}

# %% [markdown]
# **On cherche les clés**

# %%
result_api.keys()
# Out:
# dict_keys(['number', 'message', 'people'])

# %%
# On peut rentrer le tout dans une DataFrame
pd.DataFrame(result_api['people'])
# Out:
#                 name        craft
# 0     Mark Vande Hei          ISS
# 1       Pyotr Dubrov          ISS
# 2   Anton Shkaplerov          ISS
# 3       Zhai Zhigang  Shenzhou 13
# 4        Wang Yaping  Shenzhou 13
# 5         Ye Guangfu  Shenzhou 13
# 6         Raja Chari          ISS
# 7      Tom Marshburn          ISS
# 8       Kayla Barron          ISS
# 9    Matthias Maurer          ISS
# 10     Oleg Artemyev          ISS
# 11     Denis Matveev          ISS
# 12  Sergey Korsakov.          ISS

# %% [markdown]
# ### Passer des paramètres

# %%
#On passe le paramètre de race labrador directement dans l'url
url = "https://api.thedogapi.com/v1/breeds/search?q=labrador"
r = requests.get(url)
r.json()
# Out:
# [{'weight': {'imperial': '55 - 80', 'metric': '25 - 36'},
#   'height': {'imperial': '21.5 - 24.5', 'metric': '55 - 62'},
#   'id': 149,
#   'name': 'Labrador Retriever',
#   'bred_for': 'Water retrieving',
#   'breed_group': 'Sporting',
#   'life_span': '10 - 13 years',
#   'temperament': 'Kind, Outgoing, Agile, Gentle, Intelligent, Trusting, Even Tempered',
#   'reference_image_id': 'B1uW7l5VX'}]

# %%
#Plus propre, on la passe dans les paramètres
param = {"q": "labrador"}
url = "https://api.thedogapi.com/v1/breeds/search"
r = requests.get(url, params=param)
r.json()
# Out:
# [{'weight': {'imperial': '55 - 80', 'metric': '25 - 36'},
#   'height': {'imperial': '21.5 - 24.5', 'metric': '55 - 62'},
#   'id': 149,
#   'name': 'Labrador Retriever',
#   'bred_for': 'Water retrieving',
#   'breed_group': 'Sporting',
#   'life_span': '10 - 13 years',
#   'temperament': 'Kind, Outgoing, Agile, Gentle, Intelligent, Trusting, Even Tempered',
#   'reference_image_id': 'B1uW7l5VX'}]

# %%
params = {"q": "poodle"}
url = "https://api.thedogapi.com/v1/breeds/search"
r = requests.get(url, params=params)
r.json()
# Out:
# [{'weight': {'imperial': '40 - 55', 'metric': '18 - 25'},
#   'height': {'imperial': '16 - 24', 'metric': '41 - 61'},
#   'id': 195,
#   'name': 'Poodle',
#   'bred_for': 'Retrieving through water',
#   'breed_group': 'Non-Sporting',
#   'life_span': '14 - 18 years',
#   'temperament': 'Alert, Intelligent, Faithful, Active, Instinctual, Trainable'},
#  {'weight': {'imperial': '15 - 17', 'metric': '7 - 8'},
#   'height': {'imperial': '11 - 15', 'metric': '28 - 38'},
#   'id': 196,
#   'name': 'Poodle (Miniature)',
#   'life_span': '12 – 15 years',
#   'reference_image_id': 'Hkxk4ecVX'},
#  {'weight': {'imperial': '6 - 9', 'metric': '3 - 4'},
#   'height': {'imperial': '9 - 11', 'metric': '23 - 28'},
#   'id': 197,
#   'name': 'Poodle (Toy)',
#   'life_span': '18 years',
#   'reference_image_id': 'rJFJVxc4m'},
#  {'weight': {'imperial': '5 - 10', 'metric': '2 - 5'},
#   'height': {'imperial': '10', 'metric': '25'},
#   'id': 249,
#   'name': 'Toy Poodle',
#   'breed_group': 'Toy',
#   'life_span': '14 - 18 years'}]

# %% [markdown]
# #### Utiliser des acces key

# %%
url = "https://api.nasa.gov/mars-photos/api/v1/rovers/curiosity/photos"
# Replacer DEMO_KEY si vous en avez généré une
# générer une clé api : https://api.nasa.gov:443
# api_key = "MkCWZJ6NMlICFvDIXEMEGrBtOgbvV4NUInTgUOx9"
#On cherche les photos de mars prises le 1er mars 2022
api_key = "DEMO_KEY"
params = {"api_key": api_key, "earth_date": "2022-03-01"}
response = requests.get(url, params=params)
response
# Out:
# <Response [200]>

# %%
json_data = response.json()

# %%
json_data
# Out:
# {'photos': [{'id': 943583,
#    'sol': 3401,
#    'camera': {'id': 20,
#     'name': 'FHAZ',
#     'rover_id': 5,
#     'full_name': 'Front Hazard Avoidance Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/fcam/FLB_699416473EDR_F0932578FHAZ00302M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943584,
#    'sol': 3401,
#    'camera': {'id': 20,
#     'name': 'FHAZ',
#     'rover_id': 5,
#     'full_name': 'Front Hazard Avoidance Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/fcam/FRB_699416473EDR_F0932578FHAZ00302M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943585,
#    'sol': 3401,
#    'camera': {'id': 21,
#     'name': 'RHAZ',
#     'rover_id': 5,
#     'full_name': 'Rear Hazard Avoidance Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/rcam/RLB_699416600EDR_F0932578RHAZ00311M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943586,
#    'sol': 3401,
#    'camera': {'id': 21,
#     'name': 'RHAZ',
#     'rover_id': 5,
#     'full_name': 'Rear Hazard Avoidance Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/rcam/RRB_699416600EDR_F0932578RHAZ00311M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943597,
#    'sol': 3401,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/msss/03401/mcam/3401ML1015730051205711C00_DXXX.jpg',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943598,
#    'sol': 3401,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/msss/03401/mcam/3401ML1015730041205710C00_DXXX.jpg',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943599,
#    'sol': 3401,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/msss/03401/mcam/3401ML1015730031205709C00_DXXX.jpg',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943600,
#    'sol': 3401,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/msss/03401/mcam/3401ML1015730021205708C00_DXXX.jpg',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943601,
#    'sol': 3401,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/msss/03401/mcam/3401ML1015730011205707C00_DXXX.jpg',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943602,
#    'sol': 3401,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/msss/03401/mcam/3401ML1015730001205706C00_DXXX.jpg',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943603,
#    'sol': 3401,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/msss/03401/mcam/3401ML1015730051205711I01_DXXX.jpg',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943604,
#    'sol': 3401,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/msss/03401/mcam/3401ML1015730041205710I01_DXXX.jpg',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943605,
#    'sol': 3401,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/msss/03401/mcam/3401ML1015730031205709I01_DXXX.jpg',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943606,
#    'sol': 3401,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/msss/03401/mcam/3401ML1015730021205708I01_DXXX.jpg',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943607,
#    'sol': 3401,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/msss/03401/mcam/3401ML1015730011205707I01_DXXX.jpg',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943608,
#    'sol': 3401,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/msss/03401/mcam/3401ML1015730001205706I01_DXXX.jpg',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943655,
#    'sol': 3401,
#    'camera': {'id': 23,
#     'name': 'CHEMCAM',
#     'rover_id': 5,
#     'full_name': 'Chemistry and Camera Complex'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ccam/CR0_699409994EDR_F0932566CCAM04401M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943656,
#    'sol': 3401,
#    'camera': {'id': 23,
#     'name': 'CHEMCAM',
#     'rover_id': 5,
#     'full_name': 'Chemistry and Camera Complex'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ccam/CR0_699409944EDR_F0932566CCAM04401M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943657,
#    'sol': 3401,
#    'camera': {'id': 23,
#     'name': 'CHEMCAM',
#     'rover_id': 5,
#     'full_name': 'Chemistry and Camera Complex'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ccam/CR0_699409894EDR_F0932566CCAM04401M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943658,
#    'sol': 3401,
#    'camera': {'id': 23,
#     'name': 'CHEMCAM',
#     'rover_id': 5,
#     'full_name': 'Chemistry and Camera Complex'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ccam/CR0_699409844EDR_F0932566CCAM04401M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943659,
#    'sol': 3401,
#    'camera': {'id': 23,
#     'name': 'CHEMCAM',
#     'rover_id': 5,
#     'full_name': 'Chemistry and Camera Complex'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ccam/CR0_699409794EDR_F0932566CCAM04401M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943660,
#    'sol': 3401,
#    'camera': {'id': 23,
#     'name': 'CHEMCAM',
#     'rover_id': 5,
#     'full_name': 'Chemistry and Camera Complex'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ccam/CR0_699409744EDR_F0932566CCAM04401M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943661,
#    'sol': 3401,
#    'camera': {'id': 23,
#     'name': 'CHEMCAM',
#     'rover_id': 5,
#     'full_name': 'Chemistry and Camera Complex'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ccam/CR0_699409694EDR_F0932566CCAM04401M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943662,
#    'sol': 3401,
#    'camera': {'id': 23,
#     'name': 'CHEMCAM',
#     'rover_id': 5,
#     'full_name': 'Chemistry and Camera Complex'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ccam/CR0_699409644EDR_F0932566CCAM04401M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943663,
#    'sol': 3401,
#    'camera': {'id': 23,
#     'name': 'CHEMCAM',
#     'rover_id': 5,
#     'full_name': 'Chemistry and Camera Complex'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ccam/CR0_699409593EDR_F0932566CCAM04401M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943664,
#    'sol': 3401,
#    'camera': {'id': 23,
#     'name': 'CHEMCAM',
#     'rover_id': 5,
#     'full_name': 'Chemistry and Camera Complex'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ccam/CR0_699409352EDR_F0932566CCAM04401M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943665,
#    'sol': 3401,
#    'camera': {'id': 23,
#     'name': 'CHEMCAM',
#     'rover_id': 5,
#     'full_name': 'Chemistry and Camera Complex'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ccam/CR0_699409180EDR_F0932566CCAM03401M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943666,
#    'sol': 3401,
#    'camera': {'id': 23,
#     'name': 'CHEMCAM',
#     'rover_id': 5,
#     'full_name': 'Chemistry and Camera Complex'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ccam/CR0_699409122EDR_F0932566CCAM03401M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943667,
#    'sol': 3401,
#    'camera': {'id': 23,
#     'name': 'CHEMCAM',
#     'rover_id': 5,
#     'full_name': 'Chemistry and Camera Complex'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ccam/CR0_699409076EDR_F0932566CCAM03401M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943668,
#    'sol': 3401,
#    'camera': {'id': 23,
#     'name': 'CHEMCAM',
#     'rover_id': 5,
#     'full_name': 'Chemistry and Camera Complex'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ccam/CR0_699408899EDR_F0932566CCAM03401M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943669,
#    'sol': 3401,
#    'camera': {'id': 23,
#     'name': 'CHEMCAM',
#     'rover_id': 5,
#     'full_name': 'Chemistry and Camera Complex'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ccam/CR0_699408852EDR_F0932566CCAM03401M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943670,
#    'sol': 3401,
#    'camera': {'id': 23,
#     'name': 'CHEMCAM',
#     'rover_id': 5,
#     'full_name': 'Chemistry and Camera Complex'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ccam/CR0_699408806EDR_F0932566CCAM03401M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943671,
#    'sol': 3401,
#    'camera': {'id': 23,
#     'name': 'CHEMCAM',
#     'rover_id': 5,
#     'full_name': 'Chemistry and Camera Complex'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ccam/CR0_699408629EDR_F0932566CCAM03401M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943672,
#    'sol': 3401,
#    'camera': {'id': 23,
#     'name': 'CHEMCAM',
#     'rover_id': 5,
#     'full_name': 'Chemistry and Camera Complex'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ccam/CR0_699408582EDR_F0932566CCAM03401M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943673,
#    'sol': 3401,
#    'camera': {'id': 23,
#     'name': 'CHEMCAM',
#     'rover_id': 5,
#     'full_name': 'Chemistry and Camera Complex'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ccam/CR0_699408536EDR_F0932566CCAM03401M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943674,
#    'sol': 3401,
#    'camera': {'id': 23,
#     'name': 'CHEMCAM',
#     'rover_id': 5,
#     'full_name': 'Chemistry and Camera Complex'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ccam/CR0_699408354EDR_F0932566CCAM03401M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943675,
#    'sol': 3401,
#    'camera': {'id': 23,
#     'name': 'CHEMCAM',
#     'rover_id': 5,
#     'full_name': 'Chemistry and Camera Complex'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ccam/CR0_699408231EDR_F0932566CCAM02401M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943676,
#    'sol': 3401,
#    'camera': {'id': 23,
#     'name': 'CHEMCAM',
#     'rover_id': 5,
#     'full_name': 'Chemistry and Camera Complex'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ccam/CR0_699407421EDR_F0932566CCAM02401M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943677,
#    'sol': 3401,
#    'camera': {'id': 23,
#     'name': 'CHEMCAM',
#     'rover_id': 5,
#     'full_name': 'Chemistry and Camera Complex'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ccam/CR0_699407302EDR_F0932566CCAM01401M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943678,
#    'sol': 3401,
#    'camera': {'id': 23,
#     'name': 'CHEMCAM',
#     'rover_id': 5,
#     'full_name': 'Chemistry and Camera Complex'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ccam/CR0_699406591EDR_F0932566CCAM01401M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943679,
#    'sol': 3401,
#    'camera': {'id': 23,
#     'name': 'CHEMCAM',
#     'rover_id': 5,
#     'full_name': 'Chemistry and Camera Complex'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/soas/rdr/ccam/CR0_699409994PRC_F0932566CCAM04401L1.PNG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943680,
#    'sol': 3401,
#    'camera': {'id': 23,
#     'name': 'CHEMCAM',
#     'rover_id': 5,
#     'full_name': 'Chemistry and Camera Complex'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/soas/rdr/ccam/CR0_699409944PRC_F0932566CCAM04401L1.PNG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943681,
#    'sol': 3401,
#    'camera': {'id': 23,
#     'name': 'CHEMCAM',
#     'rover_id': 5,
#     'full_name': 'Chemistry and Camera Complex'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/soas/rdr/ccam/CR0_699409844PRC_F0932566CCAM04401L1.PNG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943682,
#    'sol': 3401,
#    'camera': {'id': 23,
#     'name': 'CHEMCAM',
#     'rover_id': 5,
#     'full_name': 'Chemistry and Camera Complex'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/soas/rdr/ccam/CR0_699409794PRC_F0932566CCAM04401L1.PNG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943683,
#    'sol': 3401,
#    'camera': {'id': 23,
#     'name': 'CHEMCAM',
#     'rover_id': 5,
#     'full_name': 'Chemistry and Camera Complex'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/soas/rdr/ccam/CR0_699409744PRC_F0932566CCAM04401L1.PNG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943684,
#    'sol': 3401,
#    'camera': {'id': 23,
#     'name': 'CHEMCAM',
#     'rover_id': 5,
#     'full_name': 'Chemistry and Camera Complex'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/soas/rdr/ccam/CR0_699409694PRC_F0932566CCAM04401L1.PNG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943685,
#    'sol': 3401,
#    'camera': {'id': 23,
#     'name': 'CHEMCAM',
#     'rover_id': 5,
#     'full_name': 'Chemistry and Camera Complex'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/soas/rdr/ccam/CR0_699409644PRC_F0932566CCAM04401L1.PNG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943686,
#    'sol': 3401,
#    'camera': {'id': 23,
#     'name': 'CHEMCAM',
#     'rover_id': 5,
#     'full_name': 'Chemistry and Camera Complex'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/soas/rdr/ccam/CR0_699409593PRC_F0932566CCAM04401L1.PNG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943687,
#    'sol': 3401,
#    'camera': {'id': 23,
#     'name': 'CHEMCAM',
#     'rover_id': 5,
#     'full_name': 'Chemistry and Camera Complex'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/soas/rdr/ccam/CR0_699409352PRC_F0932566CCAM04401L1.PNG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943688,
#    'sol': 3401,
#    'camera': {'id': 23,
#     'name': 'CHEMCAM',
#     'rover_id': 5,
#     'full_name': 'Chemistry and Camera Complex'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/soas/rdr/ccam/CR0_699409180PRC_F0932566CCAM03401L1.PNG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943689,
#    'sol': 3401,
#    'camera': {'id': 23,
#     'name': 'CHEMCAM',
#     'rover_id': 5,
#     'full_name': 'Chemistry and Camera Complex'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/soas/rdr/ccam/CR0_699409122PRC_F0932566CCAM03401L1.PNG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943690,
#    'sol': 3401,
#    'camera': {'id': 23,
#     'name': 'CHEMCAM',
#     'rover_id': 5,
#     'full_name': 'Chemistry and Camera Complex'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/soas/rdr/ccam/CR0_699409076PRC_F0932566CCAM03401L1.PNG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943691,
#    'sol': 3401,
#    'camera': {'id': 23,
#     'name': 'CHEMCAM',
#     'rover_id': 5,
#     'full_name': 'Chemistry and Camera Complex'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/soas/rdr/ccam/CR0_699408899PRC_F0932566CCAM03401L1.PNG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943692,
#    'sol': 3401,
#    'camera': {'id': 23,
#     'name': 'CHEMCAM',
#     'rover_id': 5,
#     'full_name': 'Chemistry and Camera Complex'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/soas/rdr/ccam/CR0_699408852PRC_F0932566CCAM03401L1.PNG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943693,
#    'sol': 3401,
#    'camera': {'id': 23,
#     'name': 'CHEMCAM',
#     'rover_id': 5,
#     'full_name': 'Chemistry and Camera Complex'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/soas/rdr/ccam/CR0_699408806PRC_F0932566CCAM03401L1.PNG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943694,
#    'sol': 3401,
#    'camera': {'id': 23,
#     'name': 'CHEMCAM',
#     'rover_id': 5,
#     'full_name': 'Chemistry and Camera Complex'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/soas/rdr/ccam/CR0_699408629PRC_F0932566CCAM03401L1.PNG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943695,
#    'sol': 3401,
#    'camera': {'id': 23,
#     'name': 'CHEMCAM',
#     'rover_id': 5,
#     'full_name': 'Chemistry and Camera Complex'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/soas/rdr/ccam/CR0_699408582PRC_F0932566CCAM03401L1.PNG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943696,
#    'sol': 3401,
#    'camera': {'id': 23,
#     'name': 'CHEMCAM',
#     'rover_id': 5,
#     'full_name': 'Chemistry and Camera Complex'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/soas/rdr/ccam/CR0_699408536PRC_F0932566CCAM03401L1.PNG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943697,
#    'sol': 3401,
#    'camera': {'id': 23,
#     'name': 'CHEMCAM',
#     'rover_id': 5,
#     'full_name': 'Chemistry and Camera Complex'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/soas/rdr/ccam/CR0_699408354PRC_F0932566CCAM03401L1.PNG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943698,
#    'sol': 3401,
#    'camera': {'id': 23,
#     'name': 'CHEMCAM',
#     'rover_id': 5,
#     'full_name': 'Chemistry and Camera Complex'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/soas/rdr/ccam/CR0_699407421PRC_F0932566CCAM02401L1.PNG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943699,
#    'sol': 3401,
#    'camera': {'id': 23,
#     'name': 'CHEMCAM',
#     'rover_id': 5,
#     'full_name': 'Chemistry and Camera Complex'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/soas/rdr/ccam/CR0_699407302PRC_F0932566CCAM01401L1.PNG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943700,
#    'sol': 3401,
#    'camera': {'id': 23,
#     'name': 'CHEMCAM',
#     'rover_id': 5,
#     'full_name': 'Chemistry and Camera Complex'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/soas/rdr/ccam/CR0_699406591PRC_F0932566CCAM01401L1.PNG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943587,
#    'sol': 3401,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ncam/NLB_699416688EDR_F0932578NCAM00284M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943588,
#    'sol': 3401,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ncam/NLB_699416664EDR_F0932578NCAM00284M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943589,
#    'sol': 3401,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ncam/NLB_699416639EDR_F0932578NCAM00284M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943590,
#    'sol': 3401,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ncam/NLB_699416559EDR_F0932578NCAM00353M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943591,
#    'sol': 3401,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ncam/NLB_699416528EDR_F0932578NCAM00353M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943592,
#    'sol': 3401,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ncam/NRB_699416688EDR_F0932578NCAM00284M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943593,
#    'sol': 3401,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ncam/NRB_699416664EDR_F0932578NCAM00284M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943594,
#    'sol': 3401,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ncam/NRB_699416639EDR_F0932578NCAM00284M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943595,
#    'sol': 3401,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ncam/NRB_699416559EDR_F0932578NCAM00353M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943596,
#    'sol': 3401,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ncam/NRB_699416528EDR_F0932578NCAM00353M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943609,
#    'sol': 3401,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ncam/NLB_699417787EDR_F0932578NCAM00354M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943610,
#    'sol': 3401,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ncam/NLB_699417748EDR_F0932578NCAM00354M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943611,
#    'sol': 3401,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ncam/NLB_699417716EDR_F0932578NCAM00354M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943612,
#    'sol': 3401,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ncam/NLB_699417684EDR_F0932578NCAM00354M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943613,
#    'sol': 3401,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ncam/NLB_699417653EDR_F0932578NCAM00354M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943614,
#    'sol': 3401,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ncam/NLB_699417611EDR_F0932578NCAM00285M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943615,
#    'sol': 3401,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ncam/NLB_699417580EDR_F0932578NCAM00285M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943616,
#    'sol': 3401,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ncam/NLB_699417548EDR_F0932578NCAM00285M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943617,
#    'sol': 3401,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ncam/NLB_699417518EDR_F0932578NCAM00285M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943618,
#    'sol': 3401,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ncam/NLB_699417434EDR_F0932578NCAM00285M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943619,
#    'sol': 3401,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ncam/NLB_699417396EDR_F0932578NCAM00285M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943620,
#    'sol': 3401,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ncam/NLB_699417372EDR_F0932578NCAM00285M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943621,
#    'sol': 3401,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ncam/NLB_699416743EDR_F0932578NCAM00284M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943622,
#    'sol': 3401,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ncam/NLB_699416719EDR_F0932578NCAM00284M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943623,
#    'sol': 3401,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ncam/NLB_699416305EDR_D0932578TRAV15060M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943624,
#    'sol': 3401,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ncam/NLB_699416118EDR_D0932572TRAV01038M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943625,
#    'sol': 3401,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ncam/NLB_699416036EDR_D0932566TRAV01038M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943626,
#    'sol': 3401,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ncam/NRB_699417787EDR_F0932578NCAM00354M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943627,
#    'sol': 3401,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ncam/NRB_699417748EDR_F0932578NCAM00354M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943628,
#    'sol': 3401,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ncam/NRB_699417716EDR_F0932578NCAM00354M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943629,
#    'sol': 3401,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ncam/NRB_699417684EDR_F0932578NCAM00354M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943630,
#    'sol': 3401,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ncam/NRB_699417653EDR_F0932578NCAM00354M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943631,
#    'sol': 3401,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ncam/NRB_699417611EDR_F0932578NCAM00285M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943632,
#    'sol': 3401,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ncam/NRB_699417580EDR_F0932578NCAM00285M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943633,
#    'sol': 3401,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ncam/NRB_699417548EDR_F0932578NCAM00285M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943634,
#    'sol': 3401,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ncam/NRB_699417518EDR_F0932578NCAM00285M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943635,
#    'sol': 3401,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ncam/NRB_699417434EDR_F0932578NCAM00285M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943636,
#    'sol': 3401,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ncam/NRB_699417396EDR_F0932578NCAM00285M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943637,
#    'sol': 3401,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ncam/NRB_699417372EDR_F0932578NCAM00285M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943638,
#    'sol': 3401,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ncam/NRB_699416743EDR_F0932578NCAM00284M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943639,
#    'sol': 3401,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ncam/NRB_699416719EDR_F0932578NCAM00284M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943640,
#    'sol': 3401,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ncam/NRB_699418160EDR_S0932578NCAM00286M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943641,
#    'sol': 3401,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ncam/NRB_699418137EDR_S0932578NCAM00286M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943642,
#    'sol': 3401,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ncam/NRB_699418114EDR_S0932578NCAM00286M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943643,
#    'sol': 3401,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ncam/NRB_699418085EDR_S0932578NCAM00286M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943644,
#    'sol': 3401,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ncam/NRB_699418056EDR_S0932578NCAM00286M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943645,
#    'sol': 3401,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ncam/NRB_699418033EDR_S0932578NCAM00286M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943646,
#    'sol': 3401,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ncam/NRB_699418010EDR_S0932578NCAM00286M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943647,
#    'sol': 3401,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ncam/NRB_699417981EDR_S0932578NCAM00286M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943648,
#    'sol': 3401,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ncam/NRB_699417952EDR_S0932578NCAM00286M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943649,
#    'sol': 3401,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ncam/NRB_699417929EDR_S0932578NCAM00286M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943650,
#    'sol': 3401,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ncam/NRB_699417900EDR_S0932578NCAM00286M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943651,
#    'sol': 3401,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ncam/NRB_699417820EDR_S0932578NCAM00286M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943652,
#    'sol': 3401,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ncam/NRB_699416305EDR_D0932578TRAV15060M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943653,
#    'sol': 3401,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ncam/NRB_699416118EDR_D0932572TRAV01038M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 943654,
#    'sol': 3401,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/ncam/NRB_699416036EDR_D0932566TRAV01038M_.JPG',
#    'earth_date': '2022-03-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}}]}

# %%
json_data.keys()
# Out:
# dict_keys(['photos'])

# %%
list_photos = json_data['photos']

# %%
# Nombre de photos
len(list_photos)
# Out:
# 118

# %%
list_photos[0]["img_src"]
# Out:
# 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03401/opgs/edr/fcam/FLB_699416473EDR_F0932578FHAZ00302M_.JPG'

# %% [markdown]
# #### Exemples avec l'api de Wikipedia

# %% [markdown]
# ### Chercher le début d'un article sur le langage Python

# %%
subject = 'Python (langage)'
url = 'https://fr.wikipedia.org/w/api.php'
params = {
        'action': 'query',
        'format': 'json',
        'titles': subject,
        'prop': 'extracts',
        'exintro': True,
        'explaintext': True,
    }
 
response = requests.get(url, params=params)
data = response.json()

# %%
data
# Out:
# {'batchcomplete': '',
#  'query': {'pages': {'2340': {'pageid': 2340,
#     'ns': 0,
#     'title': 'Python (langage)',
#     'extract': "Python (prononcé /pi.tɔ̃/) est un langage de programmation interprété, multi-paradigme et multiplateformes. Il favorise la programmation impérative structurée, fonctionnelle et orientée objet. Il est doté d'un typage dynamique fort, d'une gestion automatique de la mémoire par ramasse-miettes et d'un système de gestion d'exceptions ; il est ainsi similaire à Perl, Ruby, Scheme, Smalltalk et Tcl.\nLe langage Python est placé sous une licence libre proche de la licence BSD et fonctionne sur la plupart des plates-formes informatiques, des smartphones aux ordinateurs centraux, de Windows à Unix avec notamment GNU/Linux en passant par macOS, ou encore Android, iOS, et peut aussi être traduit en Java ou .NET. Il est conçu pour optimiser la productivité des programmeurs en offrant des outils de haut niveau et une syntaxe simple à utiliser.\nIl est également apprécié par certains pédagogues qui y trouvent un langage où la syntaxe, clairement séparée des mécanismes de bas niveau, permet une initiation aisée aux concepts de base de la programmation."}}}}

# %%
pages = data['query']['pages']

# %%
pages[list(pages.keys())[0]]['extract'][:192]
# Out:
# 'Python (prononcé /pi.tɔ̃/) est un langage de programmation interprété, multi-paradigme et multiplateformes. Il favorise la programmation impérative structurée, fonctionnelle et orientée objet.'

# %% [markdown]
# ### Chercher les article de Wikipedia France qui ont "Python" dans leur titre

# %%
query = 'python'
 
url = 'https://fr.wikipedia.org/w/api.php'
params = {
            'action':'query',
            'format':'json',
            'list':'search',
            'utf8':1,
            'srsearch':query
        }
 
data = requests.get(url, params=params).json()
 
for i in data['query']['search']:
    print(i['title'], ' - Word count: ', i['wordcount'])
# Out:
# Python (langage)  - Word count:  7484
# Monty Python  - Word count:  8936
# Python  - Word count:  232
# Monty Python : Sacré Graal !  - Word count:  3334
# PYTHON  - Word count:  641
# Python réticulé  - Word count:  1486
# Python royal  - Word count:  1261
# Python (mythologie)  - Word count:  500
# Python (serpent)  - Word count:  220
# Liste de logiciels Python  - Word count:  1559

# %% [markdown]
# #### Exercices
# #### Recherche de coordonnées géographiques d'une adresse  dans la base adresse nationale

# %% [markdown]
# **Documentation**
# - https://github.com/BaseAdresseNationale/api-fantoir/blob/master/README.md#api
# - https://adresse.data.gouv.fr/api-doc/adresse

# %% [markdown]
# **url de base :**
# https://api-adresse.data.gouv.fr/search/
# Trouver les coordonnées géographique du "8 avenue de la République à Paris"
# En utilisant request, get et au moins un paramètre

# %% [markdown]
# **Faire la liste des et Avenues de la commune de Vincennes (dans une DataFrame)**
# Attention, le code commune n'est pas la même chose que le code postal

# %% [markdown]
# Documentation
# https://github.com/BaseAdresseNationale/api-fantoir/blob/master/README.md#api
