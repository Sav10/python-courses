# %%
import numpy as np
import pandas as pd
import requests

from bs4 import BeautifulSoup

import json
import sys
from SPARQLWrapper import SPARQLWrapper, JSON
import time

# %% [markdown]
# **DOC**
# - https://ramiro.org/notebook/us-presidents-causes-of-death/
# - https://janakiev.com/blog/wikidata-mayors/
# - https://www.wikidata.org/wiki/Wikidata:SPARQL_tutorial
# - https://www.wikidata.org/wiki/Wikidata:SPARQL_query_service/queries/examples
# - https://stackoverflow.com/questions/37119412/wikidata-sparql-how-to-access-award-point-of-time-and-work-from-a-people
# - https://www.wikidata.org/wiki/Wikidata:Request_a_query/Archive/2017/10

# %% [markdown]
# ### Très bonne vidéo expliquant comment construire une requête sur Wikidata
# - https://www.youtube.com/watch?v=b3ft3CzkLYk&t=2409s

# %% [markdown]
# **Pour tester sa requète Wikidata :**
# - https://query.wikidata.org/

# %% [markdown]
# #### Une fois la requête construite, on peut la lancer

# %% [markdown]
# ### On va chercher ici tous les prix Nobel de Physique avec date de naissance et genre
# - La référence du Nobel de Physique : Q38104

# %%
endpoint_url = "https://query.wikidata.org/sparql"

query = """PREFIX wikibase: <http://wikiba.se/ontology#>
PREFIX wd: <http://www.wikidata.org/entity/>
PREFIX wdt: <http://www.wikidata.org/prop/direct/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

SELECT ?item ?itemLabel ?date ?birth ?genderLabel ?awardLabel ?countryLabel
{
    # ?item wdt:P166 wd:Q38104 .
  OPTIONAL {
  # ?item p:P166 ?awardstatement .
  # ?awardstatement ps:P166 ?award .
  # ?awardstatement pq:P585 ?date .
  # ?item wdt:P569 ?birth.
#   ?item wdt:P570 ?death .
  # ?item wdt:P21 ?gender.
  # ?item wdt:P27 ?country.
    }
     FILTER(?award = wd:Q38104).
    SERVICE wikibase:label {               # ... include the labels
        bd:serviceParam wikibase:language "[AUTO_LANGUAGE],fr"
    }
}
ORDER BY DESC(?date)"""


def get_results(endpoint_url, query):
    user_agent = "WDQS-example Python/%s.%s" % (sys.version_info[0], sys.version_info[1])
    # TODO adjust user agent; see https://w.wiki/CX6
    sparql = SPARQLWrapper(endpoint_url, agent=user_agent)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    return sparql.query().convert()


nobel_physique_dict = get_results(endpoint_url, query)

# %% [markdown]
# ### On obtient un dictionnaire, dont on cherche les premières clés pour convertir en format tabulaire

# %%
type(nobel_physique_dict)
# Out:
# dict

# %%
nobel_physique_dict.keys()
# Out:
# dict_keys(['head', 'results'])

# %%
nobel_physique_dict['results'].keys()
# Out:
# dict_keys(['bindings'])

# %% [markdown]
# ### On convertit en DataFrame

# %%
df_nobels_physics = pd.json_normalize(nobel_physique_dict['results']['bindings'])

# %%
df_nobels_physics
# Out:
#     item.type                               item.value  \
# 0         uri   http://www.wikidata.org/entity/Q109370
# 1         uri  http://www.wikidata.org/entity/Q1235614
# 2         uri  http://www.wikidata.org/entity/Q3675789
# 3         uri  http://www.wikidata.org/entity/Q3675789
# 4         uri    http://www.wikidata.org/entity/Q65807
# ..        ...                                      ...
# 310       uri    http://www.wikidata.org/entity/Q37463
# 311       uri    http://www.wikidata.org/entity/Q41269
# 312       uri    http://www.wikidata.org/entity/Q79000
# 313       uri    http://www.wikidata.org/entity/Q41688
# 314       uri    http://www.wikidata.org/entity/Q35149
#
#                                 birth.datatype birth.type  \
# 0    http://www.w3.org/2001/XMLSchema#dateTime    literal
# 1    http://www.w3.org/2001/XMLSchema#dateTime    literal
# 2    http://www.w3.org/2001/XMLSchema#dateTime    literal
# 3    http://www.w3.org/2001/XMLSchema#dateTime    literal
# 4    http://www.w3.org/2001/XMLSchema#dateTime    literal
# ..                                         ...        ...
# 310  http://www.w3.org/2001/XMLSchema#dateTime    literal
# 311  http://www.w3.org/2001/XMLSchema#dateTime    literal
# 312  http://www.w3.org/2001/XMLSchema#dateTime    literal
# 313  http://www.w3.org/2001/XMLSchema#dateTime    literal
# 314  http://www.w3.org/2001/XMLSchema#dateTime    literal
#
#               birth.value                              date.datatype  \
# 0    1931-10-25T00:00:00Z  http://www.w3.org/2001/XMLSchema#dateTime
# 1    1948-08-04T00:00:00Z  http://www.w3.org/2001/XMLSchema#dateTime
# 2    1931-09-21T00:00:00Z  http://www.w3.org/2001/XMLSchema#dateTime
# 3    1931-09-21T00:00:00Z  http://www.w3.org/2001/XMLSchema#dateTime
# 4    1952-03-24T00:00:00Z  http://www.w3.org/2001/XMLSchema#dateTime
# ..                    ...                                        ...
# 310  1859-05-15T00:00:00Z  http://www.w3.org/2001/XMLSchema#dateTime
# 311  1852-12-15T00:00:00Z  http://www.w3.org/2001/XMLSchema#dateTime
# 312  1865-05-25T00:00:00Z  http://www.w3.org/2001/XMLSchema#dateTime
# 313  1853-07-18T00:00:00Z  http://www.w3.org/2001/XMLSchema#dateTime
# 314  1845-03-27T00:00:00Z  http://www.w3.org/2001/XMLSchema#dateTime
#
#     date.type            date.value itemLabel.xml:lang itemLabel.type  \
# 0     literal  2021-01-01T00:00:00Z                 fr        literal
# 1     literal  2021-01-01T00:00:00Z                 fr        literal
# 2     literal  2021-01-01T00:00:00Z                 fr        literal
# 3     literal  2021-01-01T00:00:00Z                 fr        literal
# 4     literal  2020-01-01T00:00:00Z                 fr        literal
# ..        ...                   ...                ...            ...
# 310   literal  1903-01-01T00:00:00Z                 fr        literal
# 311   literal  1903-01-01T00:00:00Z                 fr        literal
# 312   literal  1902-01-01T00:00:00Z                 fr        literal
# 313   literal  1902-01-01T00:00:00Z                 fr        literal
# 314   literal  1901-01-01T00:00:00Z                 fr        literal
#
#             itemLabel.value genderLabel.xml:lang genderLabel.type  \
# 0          Klaus Hasselmann                   fr          literal
# 1            Giorgio Parisi                   fr          literal
# 2            Syukuro Manabe                   fr          literal
# 3            Syukuro Manabe                   fr          literal
# 4           Reinhard Genzel                   fr          literal
# ..                      ...                  ...              ...
# 310            Pierre Curie                   fr          literal
# 311         Henri Becquerel                   fr          literal
# 312           Pieter Zeeman                   fr          literal
# 313  Hendrik Antoon Lorentz                   fr          literal
# 314         Wilhelm Röntgen                   fr          literal
#
#     genderLabel.value awardLabel.xml:lang awardLabel.type  \
# 0            masculin                  fr         literal
# 1            masculin                  fr         literal
# 2            masculin                  fr         literal
# 3            masculin                  fr         literal
# 4            masculin                  fr         literal
# ..                ...                 ...             ...
# 310          masculin                  fr         literal
# 311          masculin                  fr         literal
# 312          masculin                  fr         literal
# 313          masculin                  fr         literal
# 314          masculin                  fr         literal
#
#            awardLabel.value countryLabel.xml:lang countryLabel.type  \
# 0    prix Nobel de physique                    fr           literal
# 1    prix Nobel de physique                    fr           literal
# 2    prix Nobel de physique                    fr           literal
# 3    prix Nobel de physique                    fr           literal
# 4    prix Nobel de physique                    fr           literal
# ..                      ...                   ...               ...
# 310  prix Nobel de physique                    fr           literal
# 311  prix Nobel de physique                    fr           literal
# 312  prix Nobel de physique                    fr           literal
# 313  prix Nobel de physique                    fr           literal
# 314  prix Nobel de physique                    fr           literal
#
#        countryLabel.value
# 0               Allemagne
# 1                  Italie
# 2                   Japon
# 3              États-Unis
# 4               Allemagne
# ..                    ...
# 310                France
# 311                France
# 312  Royaume des Pays-Bas
# 313  Royaume des Pays-Bas
# 314  république de Weimar
#
# [315 rows x 20 columns]

# %% [markdown]
# #### A présent, on cherche tous les prix Nobels de toutes les disciplines

# %% [markdown]
# #### On crée un dictionnaire avec les différents prix, et on met la requête dans une fonction

# %%
dict_nobels = {'chimie': 'Q44585',
 'physique': 'Q38104',
 'Litterature' :  'Q37922',
'paix' : 'Q35637',
'medecine' : 'Q80061',
'economie' : 'Q47170'}

# %%
### La fonction rechechera en fonction de la référence du code demandé, et retournera une DataFrame
def get_nobel(nobel_type):
    query = """PREFIX wikibase: <http://wikiba.se/ontology#>
    PREFIX wd: <http://www.wikidata.org/entity/>
    PREFIX wdt: <http://www.wikidata.org/prop/direct/>
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    
    SELECT ?item ?itemLabel ?date ?birth ?genderLabel ?awardLabel ?countryLabel
    {
        # ?item wdt:P166 wd:""" + nobel_type + " ." + """
      OPTIONAL {
      # ?item p:P166 ?awardstatement .
      # ?awardstatement ps:P166 ?award .
      # ?awardstatement pq:P585 ?date .
      # ?item wdt:P569 ?birth.
    #   ?item wdt:P570 ?death .
      # ?item wdt:P21 ?gender.
      # ?item wdt:P27 ?country.
        }
         FILTER(?award = wd:""" + nobel_type + ")." + """
        SERVICE wikibase:label {               # ... include the labels
            bd:serviceParam wikibase:language "[AUTO_LANGUAGE],fr"
        }
    }
    ORDER BY DESC(?date)"""
    this_result = get_results(endpoint_url, query)
    this_df = pd.json_normalize(this_result['results']['bindings'])
    return this_df

# %%
### Boucle pour aller chercher tous les prix Nobel et les sauvegarder dans une liste de DataFrame qu'on assemblera ultérieurement
all_dfs = []
all_dfs_dicts_list = []
for e in dict_nobels.items():
    this_df = get_nobel(e[1])
    all_dfs.append(this_df)
    all_dfs_dicts_list.append({'nobel_type': e[0], 'df': this_df})
    print(e[0])
    time.sleep(2)
# Out:
# chimie
# physique
# Litterature
# paix
# medecine
# economie

# %%
def find_allcountries(row, df):
    mask = ((df['birth.value'] == row['birth.value']) & (df['date.value'] == row['date.value']) &
           (df['itemLabel.value'] == row['itemLabel.value']) & (df['genderLabel.value'] == row['genderLabel.value']) & 
           (df['awardLabel.value'] == row['awardLabel.value']))
    return ', '.join(df[mask]['countryLabel.value'].values)

# %%
def calculate_age(born, thisDate):
    return thisDate.year - born.year - ((thisDate.month, thisDate.day) < (born.month, born.day))

# %%
all_nobels_df_f = all_nobels_df_f.sort_values('date')

# %%
# Un lauréat Nobel peut être de plusieurs pays, on les assemble dans une colone
for df in all_dfs:
    df['all_countries'] = df.apply(find_allcountries, args=(df,), axis=1)

#On concatène la liste de DataFrame dans une seule DF
all_dfs_concat =  pd.concat(all_dfs)

selected_cols = ['birth.value', 'date.value',
       'itemLabel.value', 'genderLabel.value','awardLabel.value','all_countries']

#On sélectionne certaines colonnes
all_nobels_df =  all_dfs_concat[selected_cols]

#On renomme les colonnes
all_nobels_df = all_nobels_df.rename(columns={'birth.value': 'birth', 
                                              'date.value' : 'date','genderLabel.value':'genre',
                                              'itemLabel.value' : 'name', 'awardLabel.value' : 'award'})

# Format des dates et calcul de l'âge
all_nobels_df['birth'] = pd.to_datetime(all_nobels_df['birth'].map(lambda x: x.split('T')[0][:5] + '12-10'))
all_nobels_df['date'] = pd.to_datetime(all_nobels_df['date'].map(lambda x: x.split('T')[0][:5] + '12-10'))
all_nobels_df['age'] = all_nobels_df.apply(lambda row: calculate_age(row['birth'], row['date']) , axis=1)

#Tri par date
all_nobels_df = all_nobels_df.sort_values(['date', 'award'])

#Il y avait des doublons, on dédoublone
all_nobels_df = all_nobels_df.drop_duplicates()

# %%
all_nobels_df
# Out:
#          birth       date                          name     genre  \
# 264 1852-12-10 1901-12-10  Jacobus Henricus Van 't Hoff  masculin
# 134 1828-12-10 1901-12-10                  Henry Dunant  masculin
# 136 1822-12-10 1901-12-10                Frédéric Passy  masculin
# 181 1839-12-10 1901-12-10               Sully Prudhomme  masculin
# 305 1854-12-10 1901-12-10        Emil Adolf von Behring  masculin
# ..         ...        ...                           ...       ...
# 2   1948-12-10 2021-12-10                Giorgio Parisi  masculin
# 3   1931-12-10 2021-12-10              Klaus Hasselmann  masculin
# 0   1960-12-10 2021-12-10                Joshua Angrist  masculin
# 2   1956-12-10 2021-12-10                    David Card  masculin
# 3   1963-12-10 2021-12-10                  Guido Imbens  masculin
#
#                                                  award  \
# 264                               prix Nobel de chimie
# 134                              prix Nobel de la paix
# 136                              prix Nobel de la paix
# 181                          prix Nobel de littérature
# 305              prix Nobel de physiologie ou médecine
# ..                                                 ...
# 2                               prix Nobel de physique
# 3                               prix Nobel de physique
# 0    prix de la Banque de Suède en sciences économi...
# 2    prix de la Banque de Suède en sciences économi...
# 3    prix de la Banque de Suède en sciences économi...
#
#                           all_countries  age
# 264                Royaume des Pays-Bas   49
# 134                      Suisse, France   73
# 136                              France   79
# 181                              France   62
# 305  royaume de Prusse, Empire allemand   47
# ..                                  ...  ...
# 2                                Italie   73
# 3                             Allemagne   90
# 0                    États-Unis, Israël   61
# 2                                Canada   65
# 3      États-Unis, Royaume des Pays-Bas   58
#
# [950 rows x 7 columns]

# %%
# Sauvegarde en csv
all_nobels_df.to_csv('data/data_nobels.csv', index=False)
